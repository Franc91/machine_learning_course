# %% [markdown]
# <a href="https://colab.research.google.com/github/Franc91/machine_learning_course/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello Colab')
# Out:
# hello Colab
